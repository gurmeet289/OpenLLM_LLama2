# %% [markdown]
#  - Open LLMs: https://github.com/eugeneyan/open-llms
#  - chat with Llama: https://www.llama2.ai/
#  - Official Llama2 website: https://llama.meta.com/llama2
#  - Llama2 github: https://github.com/meta-llama/llama

# %%
# !nvidia-smi
# Out:
# Sat Mar 16 18:04:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 57.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 47.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.3 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
#mport All the Required Libraries
from langchain.llms import HuggingFacePipeline

# %%
from transformers import AutoTokenizer

# %%
from transformers import AutoModelForCausalLM

# %%
import transformers
import torch

# %%
model="meta-llama/Llama-2-7b-chat-hf"
# model="daryl149/llama-2-7b-chat-hf"

# %%
tokenizer=AutoTokenizer.from_pretrained(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
llm=HuggingFacePipeline(pipeline=pipeline, model_kwargs={'temperature':0})

# %%
prompt="What would be a good name for a company that makes colorful socks"

# %%
print(llm(prompt))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ?
#
# Answer: Here are some suggestions for a company that makes colorful socks:
#
# 1. SoleMates: This name plays on the idea of socks being a companion for your feet, and the word "mates" implies a sense of friendship and camaraderie.
# 2. Hue & Cry: This name is a play on words that references the idea of colorful socks being a source of excitement and attention.
# 3. Toe-tally Rad: This name is a play on the phrase "totally rad," which implies that the socks are cool and exciting.
# 4. Sock It to Me: This name is a play on the phrase "sock it to me," which implies that the socks are bold and eye-catching.
# 5. Footloose & Fancy-Free: This name references the idea of being free and carefree, which could be appealing to customers looking for fun and colorful socks.
# 6. The Sock Exchange: This name implies that the company offers a wide variety of socks in different colors and styles, and the "exchange" part implies that customers can trade in their old socks for new ones.
# 7. Socktastic: This name is a play on the word "fantastic," and it implies that the socks are truly amazing and worth getting excited about.
# 8. The Sock Society: This name implies that the company is a group of people who are passionate about socks and want to share their love of them with the world.
# 9. Socks & Stories: This name references the idea that every sock has a story behind it, and the "stories" part implies that the company is committed to sharing those stories with its customers.
# 10. The Sockery: This name is a play on the word "bakery," and it implies that the company is a place where customers can come to find delicious and colorful socks.
#
# I hope these suggestions help inspire you as you come up with a name for your company!

# %%
prompt="I want to open a restaurant for  indian food. Suggest me a fence name for this"

# %%
print(llm(prompt))
# Out:
#  restaurant.
#
# Answer:
#
# Congratulations on your decision to open an Indian restaurant! Choosing a unique and memorable name for your restaurant is important to make it stand out and attract customers. Here are some suggestions for your Indian restaurant:
#
# 1. Tandoor: Tandoor is a traditional Indian clay oven used for cooking naan, tandoori chicken, and other dishes. This name would be perfect for an Indian restaurant that specializes in tandoori cuisine.
# 2. Spice Route: The spice route refers to the ancient trade route that connected India to the Mediterranean region, where spices were traded. This name would be great for an Indian restaurant that offers a variety of spicy dishes.
# 3. Curry Leaf: The curry leaf is a common ingredient in Indian cooking, and this name would be perfect for an Indian restaurant that offers a variety of curries and other dishes.
# 4. Biryani Bazaar: Biryani is a popular Indian dish made with rice, meat, and spices. This name would be great for an Indian restaurant that specializes in biryani and other rice-based dishes.
# 5. Tikka Tandoor: Tikka is a popular Indian dish made with marinated chicken cooked in a tandoor. This name would be perfect for an Indian restaurant that specializes in tikka and other chicken dishes.
# 6. Mumbai Street Food: Mumbai is known for its street food, and this name would be great for an Indian restaurant that offers a variety of street food dishes.
# 7. Rajasthani Royal: Rajasthan is a state in India known for its rich culture and cuisine. This name would be perfect for an Indian restaurant that specializes in Rajasthani cuisine.
# 8. Punjabi Palace: Punjab is a state in India known for its rich culture and cuisine. This name would be great for an Indian restaurant that offers a variety of Punjabi dishes.
# 9. Bangalore Bites: Bangalore is a city in India known for its food scene. This name would be perfect for an Indian restaurant that offers a variety of dishes from Bangalore.
# 10. Delhi Darbar: Delhi is the capital city of India, and the term "darbar" means court in Hindi. This name would be great for an Indian restaurant that offers a variety of traditional Delhi dishes.
#
# I hope these suggestions help you find the perfect name for your Indian restaurant!
